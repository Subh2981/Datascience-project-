# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df=pd.read_csv("raw.csv")

# %%
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.describe()
# Out:
#        math_score  reading_score  writing_score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race_ethnicity               1000 non-null   object
#  2   parental_level_of_education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test_preparation_course      1000 non-null   object
#  5   math_score                   1000 non-null   int64
#  6   reading_score                1000 non-null   int64
#  7   writing_score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.isnull().sum()
# Out:
# gender                         0
# race_ethnicity                 0
# parental_level_of_education    0
# lunch                          0
# test_preparation_course        0
# math_score                     0
# reading_score                  0
# writing_score                  0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.nunique()
# Out:
# gender                          2
# race_ethnicity                  5
# parental_level_of_education     6
# lunch                           2
# test_preparation_course         2
# math_score                     81
# reading_score                  72
# writing_score                  77
# dtype: int64

# %%
numeric_feature=df.select_dtypes('number')
categori_feature=df.select_dtypes('object')

# %%
numeric_feature
# Out:
#      math_score  reading_score  writing_score
# 0            72             72             74
# 1            69             90             88
# 2            90             95             93
# 3            47             57             44
# 4            76             78             75
# ..          ...            ...            ...
# 995          88             99             95
# 996          62             55             55
# 997          59             71             65
# 998          68             78             77
# 999          77             86             86
#
# [1000 rows x 3 columns]

# %%
df['total']=df['math_score']+df['reading_score']+df['writing_score']

# %%
df['Average']=df['total']/3

# %%
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score  total  \
# 0                    none          72             72             74    218
# 1               completed          69             90             88    247
# 2                    none          90             95             93    278
# 3                    none          47             57             44    148
# 4                    none          76             78             75    229
#
#      Average
# 0  72.666667
# 1  82.333333
# 2  92.666667
# 3  49.333333
# 4  76.333333

# %%
sns.histplot(data=df,x='Average',hue='gender',kde=True)
# Out:
# <Axes: xlabel='Average', ylabel='Count'>

# %% [markdown]
# ### Female avrege score is more than male aerage score

# %%
df.columns
# Out:
# Index(['gender', 'race_ethnicity', 'parental_level_of_education', 'lunch',
#        'test_preparation_course', 'math_score', 'reading_score',
#        'writing_score', 'total', 'Average'],
#       dtype='object')

# %%
sns.histplot(data=df,x='math_score',hue='gender',kde=True)
# Out:
# <Axes: xlabel='math_score', ylabel='Count'>

# %% [markdown]
# #### Male performing better in maths as compare to female

# %%
sns.histplot(data=df,x='reading_score',hue='gender',kde=True)
# Out:
# <Axes: xlabel='reading_score', ylabel='Count'>

# %% [markdown]
# ##### Femlale Performing better in Reading as  compare to male

# %%
sns.histplot(data=df,x='writing_score',hue='gender',kde=True)
# Out:
# <Axes: xlabel='writing_score', ylabel='Count'>

# %%
sns.countplot(data=df,x='gender',hue='race_ethnicity')
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
df.columns
# Out:
# Index(['gender', 'race_ethnicity', 'parental_level_of_education', 'lunch',
#        'test_preparation_course', 'math_score', 'reading_score',
#        'writing_score', 'total', 'Average'],
#       dtype='object')

# %%
sns.barplot(data=df,x='gender',y='Average',hue='race_ethnicity')
# Out:
# <Axes: xlabel='gender', ylabel='Average'>

# %% [markdown]
# #### female ethinicity group scoring more than every male ethinicity group
#
# #### group E has the Highest average score than any other Groups irrespect to any gender

# %%
sns.histplot(data=df,x='Average',hue='race_ethnicity',kde=True)
# Out:
# <Axes: xlabel='Average', ylabel='Count'>

# %%
sns.countplot(data=df,x='gender',hue='race_ethnicity')
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %% [markdown]
# ##### most people are from group c race and less people are belongs to group a ethinicity in both male and female

# %%
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score  total  \
# 0                    none          72             72             74    218
# 1               completed          69             90             88    247
# 2                    none          90             95             93    278
# 3                    none          47             57             44    148
# 4                    none          76             78             75    229
#
#      Average
# 0  72.666667
# 1  82.333333
# 2  92.666667
# 3  49.333333
# 4  76.333333

# %%
sns.histplot(data=df,x='Average',hue='parental_level_of_education',kde=True)
# Out:
# <Axes: xlabel='Average', ylabel='Count'>

# %%
sns.barplot(data=df,x='parental_level_of_education',y='Average')
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2, 3, 4, 5],
#  [Text(0, 0, "bachelor's degree"),
#   Text(1, 0, 'some college'),
#   Text(2, 0, "master's degree"),
#   Text(3, 0, "associate's degree"),
#   Text(4, 0, 'high school'),
#   Text(5, 0, 'some high school')])

# %%
sns.histplot(data=df,x='Average',hue='lunch',kde=True)
# Out:
# <Axes: xlabel='Average', ylabel='Count'>

# %%
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score  total  \
# 0                    none          72             72             74    218
# 1               completed          69             90             88    247
# 2                    none          90             95             93    278
# 3                    none          47             57             44    148
# 4                    none          76             78             75    229
#
#      Average
# 0  72.666667
# 1  82.333333
# 2  92.666667
# 3  49.333333
# 4  76.333333

# %%
sns.violinplot(data=df,x='gender',y='Average')
# Out:
# <Axes: xlabel='gender', ylabel='Average'>

# %%
sns.violinplot(data=df,x='race_ethnicity',y='Average')
# Out:
# <Axes: xlabel='race_ethnicity', ylabel='Average'>

# %%
sns.violinplot(data=df,x='parental_level_of_education',y='Average')
# Out:
# <Axes: xlabel='parental_level_of_education', ylabel='Average'>

# %%
sns.violinplot(data=df,x='lunch',y="Average")
# Out:
# <Axes: xlabel='lunch', ylabel='Average'>

# %%
sns.violinplot(data=df,x='test_preparation_course',y='Average')
# Out:
# <Axes: xlabel='test_preparation_course', ylabel='Average'>

# %%
sns.scatterplot(data=df,x='math_score',y='Average')
# Out:
# <Axes: xlabel='math_score', ylabel='Average'>

# %%
sns.scatterplot(data=df,x='reading_score',y='Average')
# Out:
# <Axes: xlabel='reading_score', ylabel='Average'>

# %%
sns.scatterplot(data=df,x='writing_score',y='Average')
# Out:
# <Axes: xlabel='writing_score', ylabel='Average'>

# %%
sns.scatterplot(data=df,x='total',y='Average')
# Out:
# <Axes: xlabel='total', ylabel='Average'>
